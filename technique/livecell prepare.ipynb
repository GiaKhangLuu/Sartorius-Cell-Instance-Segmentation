# %%
import sys
import glob
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tifffile
import imagecodecs
import imageio

# %%
sys.path.append('../sartorius/package/helper_package/')

# %%
#pip install pycocotools
#pip install imagecodecs
#pip install scikit-image

# %%
from livecell_dataset import LiveCell_Dataset

# %%
SHSY5Y_LIVECELL_TRAIN_IMAGE_FOLDER = './sartorius-cell-instance-segmentation/LIVECell_dataset_2021/images/livecell_train_val_images/SHSY5Y/'
SHSY5Y_LIVECELL_TRAIN_ANNOTATION_PATH = './sartorius-cell-instance-segmentation/LIVECell_dataset_2021/annotations/LIVECell_single_cells/shsy5y/livecell_shsy5y_train.json'
SHSY5Y_LIVECELL_VAL_ANNOTATION_PATH = './sartorius-cell-instance-segmentation/LIVECell_dataset_2021/annotations/LIVECell_single_cells/shsy5y/livecell_shsy5y_val.json'

# %%
SHAPE_TARGET = (576, 704)
SHAPE = (520, 704)

# %%
livecell_dataset = LiveCell_Dataset(image_folder=SHSY5Y_LIVECELL_TRAIN_IMAGE_FOLDER, 
                                    train_annotation_path=SHSY5Y_LIVECELL_TRAIN_ANNOTATION_PATH,
                                    val_annotation_path=SHSY5Y_LIVECELL_VAL_ANNOTATION_PATH,
                                    shape_target=SHAPE_TARGET,
                                    shape=SHAPE)

# %%
print('Number of train SHSY5Y images: ', len(livecell_dataset.train_image_df))
print('Number of val SHSY5Y images: ', len(livecell_dataset.val_image_df))
# Out:
# Number of train SHSY5Y images:  449
# Number of val SHSY5Y images:  79

# %%
livecell_dataset.train_annot_df.head()
# Out:
#                                               segmentation       area iscrowd  \
# 1564018  [[431.64, 126.36, 439.47, 131.9, 439.08, 136.4...   300.0471       0
# 1564019  [[279.35, 263.81, 282.28, 264.54, 284.72, 265....  223.89695       0
# 1564020  [[291.16, 262.34, 298.03, 262.8, 299.86, 260.8...   129.8141       0
# 1564021  [[278.04, 241.57, 288.86, 242.69, 294.08, 238....   333.7615       0
# 1564022  [[182.24, 30.73, 187.01, 19.99, 184.33, 13.43,...   234.7215       0
#
#         image_id                                               bbox  \
# 1564018  1564017  [427.25, 126.36, 18.899999999999977, 42.769999...
# 1564019  1564017  [253.26, 263.1, 38.79000000000002, 9.389999999...
# 1564020  1564017  [282.32, 260.36, 22.889999999999986, 14.610000...
# 1564021  1564017  [277.3, 234.48, 39.90999999999997, 20.14000000...
# 1564022  1564017            [170.17, 0.0, 16.840000000000003, 30.9]
#
#         category_id       id
# 1564018           1  1564018
# 1564019           1  1564019
# 1564020           1  1564020
# 1564021           1  1564021
# 1564022           1  1564022

# %%
livecell_dataset.train_image_df.head()
# Out:
#                                                  url  \
# 0  https://darwin.v7labs.com/api/images/37815/ori...
# 1  https://darwin.v7labs.com/api/images/108474/or...
# 2  https://darwin.v7labs.com/api/images/922455/or...
# 3  https://darwin.v7labs.com/api/images/47611/ori...
# 4  https://darwin.v7labs.com/api/images/47647/ori...
#
#                             file_name  height  width  \
# 0  SHSY5Y_Phase_C10_2_00d04h00m_3.tif     520    704
# 1  SHSY5Y_Phase_B10_1_03d12h00m_2.tif     520    704
# 2  SHSY5Y_Phase_D10_1_00d00h00m_4.tif     520    704
# 3  SHSY5Y_Phase_B10_2_01d12h00m_1.tif     520    704
# 4  SHSY5Y_Phase_D10_1_02d08h00m_1.tif     520    704
#
#                     original_filename       id
# 0  SHSY5Y_Phase_C10_2_00d04h00m_3.png  1564017
# 1  SHSY5Y_Phase_B10_1_03d12h00m_2.png  1420519
# 2  SHSY5Y_Phase_D10_1_00d00h00m_4.png  1419396
# 3  SHSY5Y_Phase_B10_2_01d12h00m_1.png  1498293
# 4  SHSY5Y_Phase_D10_1_02d08h00m_1.png  1439054

# %%
def rle_decode_by_image_id(image_id, df):
    SHAPE = (520, 704)
    rows = df.loc[df['id'] == image_id]
    
    # Image shape
    mask = np.full(shape=[len(rows), np.prod(SHAPE)], fill_value=0, dtype=np.uint8)
    
    for idx, (_, row) in enumerate(rows.iterrows()):
        s = row['annotation'].split()
        starts, lengths = [np.array(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
        starts -= 1
        ends = starts + lengths
        for lo, hi in zip(starts, ends):
            mask[idx, lo:hi] = True
        
    mask = mask.reshape([len(rows), *SHAPE])
    mask = np.moveaxis(mask, 0, 2)
    
    return mask

# %% [markdown]
# ## Count instances per image

# %%
ins_per_img = livecell_dataset.train_annot_df.groupby('image_id').size()

# %%
fig = plt.figure(figsize=(7, 5))

sns.histplot(x=ins_per_img.values)
plt.title('Number of instances per image')
plt.xlabel('Instances count')

plt.show()

# %%
livecell_dataset.convert_polygon_to_rle()
# Out:
# 100%|██████████| 165397/165397 [05:57<00:00, 462.45it/s]
# 100%|██████████| 28199/28199 [01:18<00:00, 360.17it/s]

# %%
livecell_dataset.train_annot_df.head()
# Out:
#                                               segmentation       area iscrowd  \
# 1564018  89136 1 89837 5 90540 8 91244 9 91949 9 92653 ...   300.0471       0
# 1564019  185410 2 186114 13 186132 7 186817 29 187520 3...  223.89695       0
# 1564020  183343 2 184044 5 184738 4 184747 7 185441 17 ...   129.8141       0
# 1564021  165739 2 166442 3 167144 5 167847 7 168550 8 1...   333.7615       0
# 1564022  173 8 876 10 1580 10 2283 12 2988 11 3692 11 4...   234.7215       0
#
#         image_id                                               bbox  \
# 1564018  1564017  [427.25, 126.36, 18.899999999999977, 42.769999...
# 1564019  1564017  [253.26, 263.1, 38.79000000000002, 9.389999999...
# 1564020  1564017  [282.32, 260.36, 22.889999999999986, 14.610000...
# 1564021  1564017  [277.3, 234.48, 39.90999999999997, 20.14000000...
# 1564022  1564017            [170.17, 0.0, 16.840000000000003, 30.9]
#
#         category_id       id
# 1564018           1  1564018
# 1564019           1  1564019
# 1564020           1  1564020
# 1564021           1  1564021
# 1564022           1  1564022

# %% [markdown]
# ## Save images to working directory

# %%
# !mkdir ./train
# !mkdir ./val

# %%
livecell_dataset.save_image_to_working_dir('train', pad_img=True)
livecell_dataset.save_image_to_working_dir('val', pad_img=True)
# Out:
# 449it [00:49,  9.12it/s]
# 79it [00:08,  9.00it/s]

# %% [markdown]
# ## Get final df

# %%
train_df = livecell_dataset.create_livecell_dataframe(img_group='train')
val_df = livecell_dataset.create_livecell_dataframe(img_group='val')
# Out:
# 165397it [00:00, 272629.89it/s]
# 28199it [00:00, 290756.00it/s]

# %%
train_df.head()
# Out:
#                                id  \
# 0  SHSY5Y_Phase_C10_2_00d04h00m_3
# 1  SHSY5Y_Phase_C10_2_00d04h00m_3
# 2  SHSY5Y_Phase_C10_2_00d04h00m_3
# 3  SHSY5Y_Phase_C10_2_00d04h00m_3
# 4  SHSY5Y_Phase_C10_2_00d04h00m_3
#
#                                           annotation cell_type
# 0  89136 1 89837 5 90540 8 91244 9 91949 9 92653 ...    shsy5y
# 1  185410 2 186114 13 186132 7 186817 29 187520 3...    shsy5y
# 2  183343 2 184044 5 184738 4 184747 7 185441 17 ...    shsy5y
# 3  165739 2 166442 3 167144 5 167847 7 168550 8 1...    shsy5y
# 4  173 8 876 10 1580 10 2283 12 2988 11 3692 11 4...    shsy5y

# %%
img_id = train_df.loc[0, 'id']
mask = rle_decode_by_image_id(img_id, train_df)
img = imageio.imread(os.path.join('./train', img_id + '.png'))

# %%
mask = livecell_dataset.pad_image(mask, 0)

# %%
merged = cv2.addWeighted(img, 0.75, 
                             np.clip(np.sum(mask, -1).astype(img.dtype), 0, 1)*255, 0.25, 0.0,)

fig = plt.figure(figsize=(10, 10))
plt.imshow(merged, cmap='gray')

# %%
img_id = np.random.choice(train_df['id'], 1)[0]
mask = rle_decode_by_image_id(img_id, train_df)
img = imageio.imread(os.path.join('./train', img_id + '.png'))

# %%
mask = livecell_dataset.pad_image(mask, 0)

# %%
merged = cv2.addWeighted(img, 0.75, 
                             np.clip(np.sum(mask, -1).astype(img.dtype), 0, 1)*255, 0.25, 0.0,)

fig = plt.figure(figsize=(10, 10))
plt.imshow(merged, cmap='gray')

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 12))

axs[0].imshow(img, cmap='gray')
axs[0].set_xlabel('Shsy5y input from LIVECell', fontsize=13)
axs[0].set_xticks([])
axs[0].set_yticks([])

axs[1].imshow(np.sum(mask, -1), cmap='seismic')
axs[1].set_xlabel('Shsy5y ground truth from LIVECell', fontsize=13)
axs[1].set_xticks([])
axs[1].set_yticks([])

plt.tight_layout()
plt.show()
